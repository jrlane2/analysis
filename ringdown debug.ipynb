# %%
# Standard library imports
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams["savefig.facecolor"] = 'white'
import matplotlib.colors as mcolors
import numpy.random as npr
from matplotlib import ticker, cm
from matplotlib.colors import LogNorm
import matplotlib.gridspec as gridspec
import pickle
import time
import csv

import C_avg_insitu as cavginsitu1
import rotating_ringdown_C_avg_insitu as cavginsitu2

# %%
dat = np.loadtxt('ringdown example data\\bare_ringdown_mode1_0.csv', delimiter=',')
daqspecs = np.loadtxt('ringdown example data\\bare_ringdown_mode1_0_daq_params.txt')

test = cavginsitu1.extract_data(dat, daqspecs, '')
test.return_Cavg_simple_ringdown('', savefolder = '', save = False)
test.plot_simple_ringdown('', savefolder = '', plot = True, save = False)
# Out:
# c:\Users\jackh\OneDrive - Yale University\MIM\NewEP3\from Justin\test repo clone\analysis\C_avg_insitu.py:278: UserWarning: Some DAq specifications passed to the simple ringdown averager have been depreciated
#  use [demod2F, deod5F, drive time, rest time, bandwidth, order, wait time]
#   warnings.warn("Some DAq specifications passed to the simple ringdown averager have been depreciated \n use [demod2F, deod5F, drive time, rest time, bandwidth, order, wait time]")

# %%
dat = np.loadtxt('ringdown example data\\bare_ringdown_mode2_0.csv', delimiter=',')
daqspecs = np.loadtxt('ringdown example data\\bare_ringdown_mode1_0_daq_params.txt')

test = cavginsitu1.extract_data(dat, daqspecs, '')
test.return_Cavg_simple_ringdown('', savefolder = '', save = False)
test.plot_simple_ringdown('', savefolder = '', plot = True, save = False)
# Out:
# c:\Users\jackh\OneDrive - Yale University\MIM\NewEP3\from Justin\test repo clone\analysis\C_avg_insitu.py:278: UserWarning: Some DAq specifications passed to the simple ringdown averager have been depreciated
#  use [demod2F, deod5F, drive time, rest time, bandwidth, order, wait time]
#   warnings.warn("Some DAq specifications passed to the simple ringdown averager have been depreciated \n use [demod2F, deod5F, drive time, rest time, bandwidth, order, wait time]")

# %%
dat = np.loadtxt('ringdown example data\\sheet_ringdown_mode1_easy.csv', delimiter=',')
daqspecs = np.loadtxt('ringdown example data\\sheet_ringdown_mode1_easy_daq_params.txt')

test = cavginsitu1.extract_data(dat, daqspecs, '')
test.return_Cavg_simple_ringdown('', savefolder = '', save = False)
test.plot_simple_ringdown('', savefolder = '', plot = True, save = False)
# Out:
# c:\Users\jackh\OneDrive - Yale University\MIM\NewEP3\from Justin\test repo clone\analysis\C_avg_insitu.py:278: UserWarning: Some DAq specifications passed to the simple ringdown averager have been depreciated
#  use [demod2F, deod5F, drive time, rest time, bandwidth, order, wait time]
#   warnings.warn("Some DAq specifications passed to the simple ringdown averager have been depreciated \n use [demod2F, deod5F, drive time, rest time, bandwidth, order, wait time]")

# %%
dat = np.loadtxt('ringdown example data\\sheet_ringdown_mode2_easy.csv', delimiter=',')
daqspecs = np.loadtxt('ringdown example data\\sheet_ringdown_mode2_easy_daq_params.txt')

test = cavginsitu1.extract_data(dat, daqspecs, '')
test.return_Cavg_simple_ringdown('', savefolder = '', save = False)
test.plot_simple_ringdown('', savefolder = '', plot = True, save = False)
# Out:
# c:\Users\jackh\OneDrive - Yale University\MIM\NewEP3\from Justin\test repo clone\analysis\C_avg_insitu.py:278: UserWarning: Some DAq specifications passed to the simple ringdown averager have been depreciated
#  use [demod2F, deod5F, drive time, rest time, bandwidth, order, wait time]
#   warnings.warn("Some DAq specifications passed to the simple ringdown averager have been depreciated \n use [demod2F, deod5F, drive time, rest time, bandwidth, order, wait time]")

# %%
dat = np.loadtxt('ringdown example data\\sheet_ringdown_mode1_hard.csv', delimiter=',')
daqspecs = np.loadtxt('ringdown example data\\sheet_ringdown_mode1_hard_daq_params.txt')

test = cavginsitu1.extract_data(dat, daqspecs, '')
test.return_Cavg_simple_ringdown('', savefolder = '', save = False)
test.plot_simple_ringdown('', savefolder = '', plot = True, save = False)
# Out:
# c:\Users\jackh\OneDrive - Yale University\MIM\NewEP3\from Justin\test repo clone\analysis\C_avg_insitu.py:278: UserWarning: Some DAq specifications passed to the simple ringdown averager have been depreciated
#  use [demod2F, deod5F, drive time, rest time, bandwidth, order, wait time]
#   warnings.warn("Some DAq specifications passed to the simple ringdown averager have been depreciated \n use [demod2F, deod5F, drive time, rest time, bandwidth, order, wait time]")

# %%
dat = np.loadtxt('ringdown example data\\sheet_ringdown_mode2_hard.csv', delimiter=',')
daqspecs = np.loadtxt('ringdown example data\\sheet_ringdown_mode2_hard_daq_params.txt')

test = cavginsitu1.extract_data(dat, daqspecs, '')
test.return_Cavg_simple_ringdown('', savefolder = '', save = False)
test.plot_simple_ringdown('', savefolder = '', plot = True, save = False)
# Out:
# c:\Users\jackh\OneDrive - Yale University\MIM\NewEP3\from Justin\test repo clone\analysis\C_avg_insitu.py:278: UserWarning: Some DAq specifications passed to the simple ringdown averager have been depreciated
#  use [demod2F, deod5F, drive time, rest time, bandwidth, order, wait time]
#   warnings.warn("Some DAq specifications passed to the simple ringdown averager have been depreciated \n use [demod2F, deod5F, drive time, rest time, bandwidth, order, wait time]")

# %%
np.unwrap(np.angle(test.C5avg))[40]%(2*np.pi)
# Out:
# 0.0

# %%
test.TTL_avg_off + test.demod5_index_wait
# Out:
# 40

# %%
test = cavginsitu1.extract_data(dat, daqspecs, '')
test.return_Cavg_data('', savefolder = '', save = False)
test.plot_simple_ringdown('', savefolder = '', plot = True, save = False)
# Out:
# c:\Users\jackh\OneDrive - Yale University\MIM\NewEP3\from Justin\test repo clone\analysis\C_avg_insitu.py:278: UserWarning: Some DAq specifications passed to the simple ringdown averager have been depreciated
#  use [demod2F, deod5F, drive time, rest time, bandwidth, order, wait time]
#   warnings.warn("Some DAq specifications passed to the simple ringdown averager have been depreciated \n use [demod2F, deod5F, drive time, rest time, bandwidth, order, wait time]")

# %%
plt.plot(np.angle(test.C5stack)[40:50])
np.shape(test.C5stack)
# Out:
# (177, 70)

# %%
print(test.shift)
print(test.demod5_index_wait)
# Out:
# 0.001
# 4

# %%
plt.plot(np.angle(test.stackS[0,:,3])- np.angle(test.C5stack[:,0]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-cb6c509d311f> in <module>
# ----> 1 plt.plot(np.angle(test.stackS[0,:,3])- np.angle(test.C5stack[:,0]))
#       2
#
# AttributeError: 'extract_data' object has no attribute 'stackS'

# %%
test.i2stackS - test.start_avg_index
# Out:
# array([1444, 1444, 1444, 1444, 1444, 1444, 1444, 1444, 1444, 1444, 1444,
#        1444, 1444, 1444, 1444, 1444, 1444, 1444,  382], dtype=int64)

# %%
test.time[test.start_avg_index] + test.start_trimT + test.setresttime - test.k2 + test.t_wait
# Out:
# array([0.44080618, 0.88940595, 1.33800572, 1.78632755, 2.23492732,
#        2.68352709, 3.13212687, 3.58072664, 4.02932641, 4.47792618,
#        4.92652595, 5.37512572, 5.82372549, 6.27232527, 6.72092504,
#        7.16952481, 7.61812458, 8.06644641, 8.51504618])

# %%
test.time[test.driveOFF_index] + test.setresttime - test.k2 + test.t_wait
# Out:
# array([0.44081212, 0.88941189, 1.33801167, 1.78633349, 2.23493327,
#        2.68353304, 3.13213281, 3.58073258, 4.02933235, 4.47793212,
#        4.92653189, 5.37513167, 5.82373144, 6.27233121, 6.72093098,
#        7.16953075, 7.61813052, 8.06645235, 8.51505212])

# %%
(test.start_trimT + test.setresttime - test.k2 + test.t_wait)/test.dtdi
# Out:
# 1443.9597359782472

# %%
test.time[test.start_avg_index] - test.time[test.driveOFF_index]
# Out:
# array([-0.01000594, -0.01000594, -0.01000594, -0.01000594, -0.01000594,
#        -0.01000594, -0.01000594, -0.01000594, -0.01000594, -0.01000594,
#        -0.01000594, -0.01000594, -0.01000594, -0.01000594, -0.01000594,
#        -0.01000594, -0.01000594, -0.01000594, -0.01000594])

# %%
test.start_trimT
# Out:
# 0.01

# %%
def stackem_aligned(data, start_indicies, length, phasealign_index = 0):
    '''
    break up a 1D array data into a 2D array
    '''
    if start_indicies[-1] + length > len(data):
        k = len(start_indicies) - 1
    else:
        k = len(start_indicies)

    stack = np.zeros((length, k), dtype = 'complex_')
    for i in range(k):
        phasor_offset = np.exp(1j*np.angle(data[start_indicies[i] + phasealign_index]))
        stack[:,i] = data[start_indicies[i]:start_indicies[i]+length]/phasor_offset
    
    return stack

# %%
d = stackem_aligned(test.C2, test.start_avg_index, 1440, phasealign_index = 35)
plt.plot(np.real(d))

# %%
plt.plot(np.angle(np.average(d, axis = 1)))

# %%
(test.t_wait + test.setresttime)/np.diff(test.time)[3]
# Out:
# 1443.9641889677155

# %%
test.i2stackS - test.start_avg_index
# Out:
# array([1444, 1444, 1444, 1444, 1444, 1444, 1444, 1444, 1444, 1444, 1444,
#        1444, 1444, 1444, 1444, 1444, 1444, 1444,  382], dtype=int64)

# %%
test.t2stackS
# Out:
# array([0.44081212, 0.88941189, 1.33801167, 1.78633349, 2.23493327,
#        2.68353304, 3.13213281, 3.58073258, 4.02933235, 4.47793212,
#        4.92653189, 5.37513167, 5.82373144, 6.27233121, 6.72093098,
#        7.16953075, 7.61813052, 8.06645235, 8.51505212])

# %%
test.tloopstartS + test.setresttime - test.k2
# Out:
# array([0.44081212, 0.88941189, 1.33801167, 1.78633349, 2.23493327,
#        2.68353304, 3.13213281, 3.58073258, 4.02933235, 4.47793212,
#        4.92653189, 5.37513167, 5.82373144, 6.27233121, 6.72093098,
#        7.16953075, 7.61813052, 8.06645235, 8.51505212])

# %%
# Standard library imports
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams["savefig.facecolor"] = 'white'
import matplotlib.colors as mcolors
import numpy.random as npr
from matplotlib import ticker, cm
from matplotlib.colors import LogNorm
import matplotlib.gridspec as gridspec
import pickle
import time
import csv

import C_avg_insitu as cavginsitu1
import rotating_ringdown_dynamics_C_avg_insitu_v3DEBUG as cavginsitu2

# %%
dat = np.loadtxt('loop example data\\mode_1_bare_0_0.csv', delimiter=',')
daqspecs = np.loadtxt('loop example data\\mode_1_bare_0_0_daq_params.txt')

testO = cavginsitu2.extract_data(dat, daqspecs, '')
testO.return_Cavg_data('', savefolder = '', save = False)
testO.plot_all('', savefolder = '', plot = True, save = False)

testN = cavginsitu1.extract_data(dat, daqspecs, '', measurement_type= 'prep loop ringdown')
testN.return_Cavg_interleaved_ringdown('', savefolder = '', save = False)
testN.plot_all('', savefolder = '', plot = True, save = False)
# Out:
# DEBUG KillNaN2:  [0, 126487]

# %%
dat = np.loadtxt('loop example data\\mode_2_bare_0_0.csv', delimiter=',')
daqspecs = np.loadtxt('loop example data\\mode_2_bare_0_0_daq_params.txt')

testO = cavginsitu2.extract_data(dat, daqspecs, '')
testO.return_Cavg_data('', savefolder = '', save = False)
testO.plot_all('', savefolder = '', plot = True, save = False)

testN = cavginsitu1.extract_data(dat, daqspecs, '', measurement_type= 'prep loop ringdown')
testN.return_Cavg_interleaved_ringdown('', savefolder = '', save = False)
testN.plot_all('', savefolder = '', plot = True, save = False)
# Out:
# c:\Users\jackh\OneDrive - Yale University\MIM\NewEP3\from Justin\test repo clone\analysis\C_avg_insitu.py:539: UserWarning: DAq specification ```iters``` hase been depreciated
#  use [demod2F, deod5F, loop time, drive time, rest time, bandwidth, order, wait time, prep time]
#   warnings.warn("DAq specification ```iters``` hase been depreciated \n use [demod2F, deod5F, loop time, drive time, rest time, bandwidth, order, wait time, prep time]")

# %%
dat = np.loadtxt('loop example data\\mode_2_forward_0_0.csv', delimiter=',')
daqspecs = np.loadtxt('loop example data\\mode_2_forward_0_0_daq_params.txt')

testO = cavginsitu2.extract_data(dat, daqspecs, '')
testO.return_Cavg_data('', savefolder = '', save = False)
testO.plot_all('', savefolder = '', plot = True, save = False)

testN = cavginsitu1.extract_data(dat, daqspecs, '', measurement_type= 'prep loop ringdown')
testN.return_Cavg_interleaved_ringdown('', savefolder = '', save = False)
testN.plot_all('', savefolder = '', plot = True, save = False)
# Out:
# DEBUG KillNaN2:  [0, 592439]
# c:\Users\jackh\OneDrive - Yale University\MIM\NewEP3\from Justin\test repo clone\analysis\C_avg_insitu.py:539: UserWarning: DAq specification ```iters``` hase been depreciated
#  use [demod2F, deod5F, loop time, drive time, rest time, bandwidth, order, wait time, prep time]
#   warnings.warn("DAq specification ```iters``` hase been depreciated \n use [demod2F, deod5F, loop time, drive time, rest time, bandwidth, order, wait time, prep time]")

# %%
dat = np.loadtxt('loop example data\\mode_2_forward_17_0.csv', delimiter=',')
daqspecs = np.loadtxt('loop example data\\mode_2_forward_17_0_daq_params.txt')

testO = cavginsitu2.extract_data(dat, daqspecs, '')
testO.return_Cavg_data('', savefolder = '', save = False)
testO.plot_all('', savefolder = '', plot = True, save = False)

testN = cavginsitu1.extract_data(dat, daqspecs, '', measurement_type= 'prep loop ringdown')
testN.return_Cavg_interleaved_ringdown('blooppp', savefolder = 'savetest', save = True)
testN.plot_all('blooppp', savefolder = 'savetest', plot = True, save = True)
# Out:
# DEBUG KillNaN2:  [0, 470609]
# c:\Users\jackh\OneDrive - Yale University\MIM\NewEP3\from Justin\test repo clone\analysis\C_avg_insitu.py:539: UserWarning: DAq specification ```iters``` hase been depreciated
#  use [demod2F, deod5F, loop time, drive time, rest time, bandwidth, order, wait time, prep time]
#   warnings.warn("DAq specification ```iters``` hase been depreciated \n use [demod2F, deod5F, loop time, drive time, rest time, bandwidth, order, wait time, prep time]")
